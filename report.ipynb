# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
report = pd.read_csv("report.csv")

# %%
report
# Out:
#           key  true_angle  pred_angle  usage
# 0        left    0.200000   -0.174556   none
# 1      center    0.000000   -0.354326   none
# 2       right   -0.200000   -0.429127   none
# 3        left    0.200000   -0.112495   none
# 4      center    0.000000   -0.366351   none
# 5       right   -0.200000   -0.425945   none
# 6        left    0.200000   -0.185734   none
# 7      center    0.000000   -0.351374   none
# 8       right   -0.200000   -0.403488   none
# 9        left    0.200000   -0.096731   none
# 10     center    0.000000   -0.363199   none
# 11      right   -0.200000   -0.401227   none
# 12       left    0.200000   -0.189020   none
# 13     center    0.000000   -0.366573   none
# 14      right   -0.200000   -0.414350   none
# 15       left    0.134272   -0.249587   none
# 16     center   -0.065728   -0.389563   none
# 17      right   -0.265728   -0.434005   none
# 18       left    0.082629   -0.102422   none
# 19     center   -0.117371   -0.365562   none
# ...

# %%
report_train = report[report["usage"] == 'train']
report_valid = report[report["usage"] == 'valid']
report_unused = report[report["usage"] == 'none']

# %%
report_train[report_train["key"] == "center"].plot.scatter("true_angle", "pred_angle")

# %%
report_valid.plot.scatter("true_angle", "pred_angle")

# %%
report_unused.plot.scatter("true_angle", "pred_angle")
